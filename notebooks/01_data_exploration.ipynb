# %% [markdown]
# # 01 - Data Exploration
#
# ## Objective
# Understand dataset structure, quality, missing values, and basic patterns before preprocessing or modeling.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./../data/openaq_location_6358.csv")

# %%
df2 = pd.read_csv("./../data/openaq_location_6358_set2.csv")

# %%
df.head()
# Out:
#    location_id                  location_name parameter  value   unit  \
# 0         6358  Mandir Marg, New Delhi - DPCC      pm10  269.0  µg/m³
# 1         6358  Mandir Marg, New Delhi - DPCC      pm10  285.0  µg/m³
# 2         6358  Mandir Marg, New Delhi - DPCC      pm10  285.0  µg/m³
# 3         6358  Mandir Marg, New Delhi - DPCC      pm10  285.0  µg/m³
# 4         6358  Mandir Marg, New Delhi - DPCC      pm10  285.0  µg/m³
#
#             datetimeUtc              datetimeLocal      timezone   latitude  \
# 0  2026-01-01T00:15:00Z  2026-01-01T05:45:00+05:30  Asia/Kolkata  28.636429
# 1  2026-01-01T00:30:00Z  2026-01-01T06:00:00+05:30  Asia/Kolkata  28.636429
# 2  2026-01-01T00:45:00Z  2026-01-01T06:15:00+05:30  Asia/Kolkata  28.636429
# 3  2026-01-01T01:00:00Z  2026-01-01T06:30:00+05:30  Asia/Kolkata  28.636429
# 4  2026-01-01T01:15:00Z  2026-01-01T06:45:00+05:30  Asia/Kolkata  28.636429
#
#    longitude  country_iso  isMobile  isMonitor  \
# ...

# %%
df2.head()
# Out:
#    location_id                  location_name parameter  value unit  \
# 0         6358  Mandir Marg, New Delhi - DPCC        co   3.39  ppb
# 1         6358  Mandir Marg, New Delhi - DPCC        co   3.38  ppb
# 2         6358  Mandir Marg, New Delhi - DPCC        co   3.29  ppb
# 3         6358  Mandir Marg, New Delhi - DPCC        co   3.18  ppb
# 4         6358  Mandir Marg, New Delhi - DPCC        co   3.16  ppb
#
#             datetimeUtc              datetimeLocal      timezone   latitude  \
# 0  2026-01-01T00:15:00Z  2026-01-01T05:45:00+05:30  Asia/Kolkata  28.636429
# 1  2026-01-01T00:30:00Z  2026-01-01T06:00:00+05:30  Asia/Kolkata  28.636429
# 2  2026-01-01T00:45:00Z  2026-01-01T06:15:00+05:30  Asia/Kolkata  28.636429
# 3  2026-01-01T01:00:00Z  2026-01-01T06:30:00+05:30  Asia/Kolkata  28.636429
# 4  2026-01-01T01:15:00Z  2026-01-01T06:45:00+05:30  Asia/Kolkata  28.636429
#
#    longitude  country_iso  isMobile  isMonitor  \
# 0  77.201067          NaN       NaN        NaN
# ...
